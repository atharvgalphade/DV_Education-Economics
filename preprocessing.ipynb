# %%
import pandas as pd
import numpy as np

# %%
most_recent_Cohorts=pd.read_csv("Most-Recent-Cohorts-Field-of-Study.csv")
most_recent_Cohorts.head()
# Out:
#      UNITID  OPEID6                    INSTNM CONTROL  MAIN  CIPCODE  \
# 0  100654.0    1002  Alabama A & M University  Public     1      100
# 1  100654.0    1002  Alabama A & M University  Public     1      101
# 2  100654.0    1002  Alabama A & M University  Public     1      109
# 3  100654.0    1002  Alabama A & M University  Public     1      110
# 4  100654.0    1002  Alabama A & M University  Public     1      110
#
#                                  CIPDESC  CREDLEV           CREDDESC  \
# 0                            Agriculture        3  Bachelor's Degree
# 1  Agricultural Business and Management.        3  Bachelor's Degree
# 2                       Animal Sciences.        3  Bachelor's Degree
# 3           Food Science and Technology.        3  Bachelor's Degree
# 4           Food Science and Technology.        5    Master's Degree
#
#    IPEDSCOUNT1  ...  EARN_COUNT_PELL_WNE_5YR EARN_PELL_WNE_MDN_5YR  \
# ...

# %%
salaries_by_clgtype=pd.read_csv("salaries-by-college-type.csv")
salaries_by_clgtype.head()
# Out:
#                                     School Name  School Type  \
# 0         Massachusetts Institute of Technology  Engineering
# 1            California Institute of Technology  Engineering
# 2                           Harvey Mudd College  Engineering
# 3  Polytechnic University of New York, Brooklyn  Engineering
# 4                                  Cooper Union  Engineering
#
#   Starting Median Salary Mid-Career Median Salary  \
# 0             $72,200.00              $126,000.00
# 1             $75,500.00              $123,000.00
# 2             $71,800.00              $122,000.00
# 3             $62,400.00              $114,000.00
# 4             $62,200.00              $114,000.00
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $76,800.00                        $99,200.00
# 1                               NaN                       $104,000.00
# 2                               NaN                        $96,000.00
# ...

# %%
salaries_by_region=pd.read_csv("salaries-by-region.csv")
salaries_by_region.head()
# Out:
#                           School Name      Region Starting Median Salary  \
# 0                 Stanford University  California             $70,400.00
# 1  California Institute of Technology  California             $75,500.00
# 2                 Harvey Mudd College  California             $71,800.00
# 3  University of California, Berkeley  California             $59,900.00
# 4                  Occidental College  California             $51,900.00
#
#   Mid-Career Median Salary Mid-Career 10th Percentile Salary  \
# 0              $129,000.00                        $68,400.00
# 1              $123,000.00                               NaN
# 2              $122,000.00                               NaN
# 3              $112,000.00                        $59,500.00
# 4              $105,000.00                               NaN
#
#   Mid-Career 25th Percentile Salary Mid-Career 75th Percentile Salary  \
# 0                        $93,100.00                       $184,000.00
# ...

# %%
Degree_pay=pd.read_csv("degrees-that-pay-back.csv")

# %%
Degree_pay.head()
# Out:
#                    Major Starting Median Salary Mid-Career Median Salary  \
# 0             Accounting             $46,000.00               $77,100.00
# 1  Aerospace Engineering             $57,700.00              $101,000.00
# 2            Agriculture             $42,600.00               $71,900.00
# 3           Anthropology             $36,800.00               $61,500.00
# 4           Architecture             $41,600.00               $76,800.00
#
#    Percent change from Starting to Mid-Career Salary  \
# 0                                               67.6
# 1                                               75.0
# 2                                               68.8
# 3                                               67.1
# 4                                               84.6
#
#   Mid-Career 10th Percentile Salary Mid-Career 25th Percentile Salary  \
# 0                        $42,200.00                        $56,100.00
# ...

# %%
Degree_pay['Major'] = Degree_pay['Major'].str.strip().str.lower()

# %%
matching_values = Degree_pay["Major"].unique()

# %%
matching_values
# Out:
# array(['accounting', 'aerospace engineering', 'agriculture',
#        'anthropology', 'architecture', 'art history', 'biology',
#        'business management', 'chemical engineering', 'chemistry',
#        'civil engineering', 'communications', 'computer engineering',
#        'computer science', 'construction', 'criminal justice', 'drama',
#        'economics', 'education', 'electrical engineering', 'english',
#        'film', 'finance', 'forestry', 'geography', 'geology',
#        'graphic design', 'health care administration', 'history',
#        'hospitality & tourism', 'industrial engineering',
#        'information technology (it)', 'interior design',
#        'international relations', 'journalism',
#        'management information systems (mis)', 'marketing', 'math',
#        'mechanical engineering', 'music', 'nursing', 'nutrition',
#        'philosophy', 'physician assistant', 'physics',
#        'political science', 'psychology', 'religion', 'sociology',
# ...

# %%
Degree_pay["Major"].count()
# Out:
# 50

# %%
most_recent_Cohorts["CIPDESC"].unique()
# Out:
# array(['Agriculture', 'Agricultural Business and Management.',
#        'Animal Sciences.', 'Food Science and Technology.',
#        'Plant Sciences.',
#        'Agriculture, Agriculture Operations, and Related Sciences, Other.',
#        'Forestry', 'City/Urban, Community and Regional Planning.',
#        'Ethnic, Cultural Minority, Gender, and Group Studies.',
#        'Communication and Media Studies.',
#        'Audiovisual Communications Technologies/Technicians.',
#        'Computer and Information Sciences, General.',
#        'Education, General.',
#        'Educational Administration and Supervision.',
#        'Special Education and Teaching.',
#        'Teacher Education and Professional Development, Specific Levels and Methods.',
#        'Teacher Education and Professional Development, Specific Subject Areas.',
#        'Civil Engineering',
#        'Electrical, Electronics and Communications Engineering.',
#        'Mechanical Engineering', 'Engineering, Other.',
# ...

# %%
most_recent_Cohorts['CIPDESC'] = most_recent_Cohorts['CIPDESC'].str.strip().str.lower()

# %%
most_recent_Cohorts['CIPDESC']
# Out:
# 0                                               agriculture
# 1                     agricultural business and management.
# 2                                          animal sciences.
# 3                              food science and technology.
# 4                              food science and technology.
#                                 ...
# 229183                          business/commerce, general.
# 229184                                           accounting
# 229185    business operations support and assistant serv...
# 229186    business operations support and assistant serv...
# 229187                                            marketing
# Name: CIPDESC, Length: 229188, dtype: object

# %% [markdown]
# This will help to reduce the rows to the degrees that are in other database.

# %%
most_recent_Cohorts_FD = most_recent_Cohorts[most_recent_Cohorts['CIPDESC'].isin(matching_values)]

# %%
print(most_recent_Cohorts['CIPDESC'].isin(matching_values)[most_recent_Cohorts['CIPDESC'].isin(matching_values)])
# Out:
# 0         True
# 10        True
# 28        True
# 30        True
# 32        True
#           ...
# 229174    True
# 229180    True
# 229182    True
# 229184    True
# 229187    True
# Name: CIPDESC, Length: 75924, dtype: bool

# %%
most_recent_Cohorts_FD.to_csv("most_recent_Cohorts_FD.csv",index=False)

# %%
most_recent_Cohorts_FD
# Out:
#           UNITID  OPEID6                        INSTNM CONTROL  MAIN  CIPCODE  \
# 0       100654.0    1002      Alabama A & M University  Public     1      100
# 10      100654.0    1002      Alabama A & M University  Public     1      305
# 28      100654.0    1002      Alabama A & M University  Public     1     1408
# 30      100654.0    1002      Alabama A & M University  Public     1     1419
# 32      100654.0    1002      Alabama A & M University  Public     1     1503
# ...          ...     ...                           ...     ...   ...      ...
# 229174       NaN   43006  Southeast New Mexico College  Public     1     4301
# 229180       NaN   43006  Southeast New Mexico College  Public     1     5107
# 229182       NaN   43006  Southeast New Mexico College  Public     1     5138
# 229184       NaN   43006  Southeast New Mexico College  Public     1     5203
# 229187       NaN   43006  Southeast New Mexico College  Public     1     5214
#
# ...

# %% [markdown]
# Now we have the dataset that has all the degrees as other database.

# %%
salaries_by_clgtype["School Name"].unique()
# Out:
# array(['Massachusetts Institute of Technology',
#        'California Institute of Technology', 'Harvey Mudd College',
#        'Polytechnic University of New York, Brooklyn', 'Cooper Union',
#        'Worcester Polytechnic Institute', 'Carnegie Mellon University ',
#        'Rensselaer Polytechnic Institute',
#        'Georgia Institute of Technology', 'Colorado School of Mines',
#        'Stevens Institute of Technology',
#        'Illinois Institute of Technology',
#        'Wentworth Institute of Technology',
#        'Virginia Polytechnic Institute and State University',
#        'South Dakota School of Mines & Technology',
#        'New Mexico Institute of Mining and Technology',
#        'Rochester Institute of Technology',
#        'Embry-Riddle Aeronautical University ',
#        'Tennessee Technological University',
#        'University of Illinois at Urbana-Champaign',
#        'University of Maryland, College Park',
#        'University of California, Santa Barbara',
# ...

# %%
universities_to_remove = [
    'Polytechnic University of New York',
    'South Dakota School of Mines & Technology',
    'Louisiana State University (LSU)',
    'University of Alabama, Tuscaloosa',
    'University of Tennessee',
    'Evergreen State College',
    'University of Illinois at Urbana-Champaign (UIUC)',
    'Texas A&M University',
    'University of Missouri - Rolla (UMR)',
    'University of California, Santa Barbara (UCSB)',
    'University of Michigan',
    'Rutgers University',
    'University of Colorado - Denver',
    'State University of New York (SUNY) at Farmingdale',
    'University of Oklahoma',
    'University of North Carolina at Chapel Hill (UNCH)',
    'University of North Carolina at Chapel Hill (UNCH)',
    'University of California, Riverside (UCR)',
    'State University of New York (SUNY) at Geneseo',
    'University of Missouri - Columbia', 'University of Nebraska',
    'University of Texas at Arlington (UTA)',
    'Northern Illinois University (NIU)', 'Oklahoma State University',
    'University of North Dakota',
    'California State University, Northridge (CSUN)',
    'University of Houston (UH)', 'New Mexico State University',
    'Lamar University', 'Mississippi State University (MSU)',
    'Colorado State University (CSU)', 'Kansas State University (KSU)',
    'University of Wyoming (UW)', 'Utah State University',
    'University of Wisconsin (UW) - Platteville',
    'University of Oregon', 'University of Kentucky (UK)',
    'University of Massachusetts (UMass) - Boston',
    'University of Maryland Baltimore County (UMBC)',
    'North Dakota State University (NDSU)',
    'State University of New York (SUNY) at Oswego',
    'University of Massachusetts (UMass) - Dartmouth',
    'Montana State University - Bozeman',
    'State University of New York (SUNY) at Oneonta',
    'University of Louisiana (UL) at Lafayette',
    'State University of New York (SUNY) at Plattsburgh',
    'Wayne State University', 'University of Hawaii',
    'University of Toledo', 'Florida International University (FIU)',
    'University of Wisconsin (UW) - Whitewater',
    'Western Washington University',
    'Minnesota State University - Mankato',
    'University of Wisconsin (UW) - Milwaukee',
    'University of Arkansas - Monticello (UAM)',
    'Penn State - Harrisburg',
    'University of North Carolina at Charlotte (UNCC)',
    'Georgia State University', 'Western Michigan University (WMU)',
    'South Dakota State University (SDSU)', 'Idaho State University',
    'Illinois State University', 'Cleveland State University',
    'University of Alaska, Anchorage', 'Fitchburg State College',
    'University of Nebraska at Omaha',
    'Southern Illinois University Carbondale',
    'University of Texas at El Paso (UTEP)',
    'California State University, Dominguez Hills (CSUDH)',
    'University Of Maine', 'Eastern Michigan University',
    'Bowling Green State University', 'University of Montana',
    'University of Central Florida (UCF)',
    'University of South Carolina',
    'University of Nevada, Las Vegas (UNLV)',
    'St. Cloud State University',
    'University of Wisconsin (UW) - Parkside',
    'California State University (CSU), Stanislaus',
    'Humboldt State University', 'Florida Atlantic University (FAU)',
    'Portland State University (PSU)', 'Eastern Washington University',
    'University of Texas at San Antonio (UTSA)', 'University of Akron',
    'State University of New York (SUNY) at Potsdam',
    'University of Alabama at Birmingham (UAB)',
    'University of Memphis (U of M)', 'Boise State University (BSU)',
    'Missouri State University (MSU)',
    'University of Wisconsin (UW) - La Crosse',
    'Appalachian State University',
    'Virginia Commonwealth University (VCU)',
    'University of Wisconsin (UW) - Stout',
    'East Carolina University (ECU)', 'Utah Valley State College',
    'University of Missouri - St. Louis (UMSL)',
    'Western Carolina University',
    'University of Wisconsin (UW) - Oshkosh',
    'State University of New York (SUNY) at Fredonia',
    'University of Missouri - Kansas City (UMKC)',
    'University of Wisconsin (UW) - Eau Claire',
    'Ball State University (BSU)',
    'University of North Carolina at Wilmington (UNCW)',
    'University of Wisconsin (UW) - Stevens Point',
    'University of Southern Maine', 'Arkansas State University (ASU)',
    'Kent State University', 'Tarleton State University (TSU)',
    'University of Wisconsin (UW) - Green Bay',
    'Morehead State University', 'Austin Peay State University',
    'Pittsburg State University', 'Southern Utah University',
    'Montana State University - Billings',
    'Black Hills State University'
]

salaries_by_clgtype_Filtered = salaries_by_clgtype[~salaries_by_clgtype['School Name'].isin(universities_to_remove)]

# %%
salaries_by_clgtype_Filtered['School Name'].count()
# Out:
# 152

# %%
salaries_by_clgtype_Filtered['School Name']=salaries_by_clgtype_Filtered['School Name'].str.strip().str.lower()
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_32708\2177668617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   salaries_by_clgtype_Filtered['School Name']=salaries_by_clgtype_Filtered['School Name'].str.strip().str.lower()

# %%
salaries_by_clgtype_Filtered.to_csv('salaries_by_clgtype_Filtered.csv',index=False)

# %%
most_recent_Cohorts_FD['INSTNM']=most_recent_Cohorts_FD['INSTNM'].str.strip().str.lower()
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_32708\1963926801.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   most_recent_Cohorts_FD['INSTNM']=most_recent_Cohorts_FD['INSTNM'].str.strip().str.lower()

# %%
matching_names=salaries_by_clgtype_Filtered['School Name'].unique()

# %%
most_recent_Cohorts_FD=most_recent_Cohorts_FD[most_recent_Cohorts_FD['INSTNM'].isin(matching_names)]

# %%
most_recent_Cohorts_FD['INSTNM'].count()
# Out:
# 2938

# %%
most_recent_Cohorts_FD.to_csv('most_recent_Cohorts_FD.csv',index=False)

# %%
salaries_by_region
# Out:
#                                          School Name        Region  \
# 0                                Stanford University    California
# 1           California Institute of Technology (CIT)    California
# 2                                Harvey Mudd College    California
# 3                 University of California, Berkeley    California
# 4                                 Occidental College    California
# ..                                               ...           ...
# 315   State University of New York (SUNY) at Potsdam  Northeastern
# 316                               Niagara University  Northeastern
# 317  State University of New York (SUNY) at Fredonia  Northeastern
# 318                     University of Southern Maine  Northeastern
# 319                                    Mercy College  Northeastern
#
#     Starting Median Salary Mid-Career Median Salary  \
# 0               $70,400.00              $129,000.00
# 1               $75,500.00              $123,000.00
# ...

# %%
salaries_by_region['School Name']=salaries_by_region['School Name'].str.strip().str.lower()

# %%
salaries_by_region_Filtered=salaries_by_region[salaries_by_region['School Name'].isin(matching_names)]

# %%
salaries_by_region_Filtered['School Name'].unique()
# Out:
# array(['california institute of technology', 'harvey mudd college',
#        'university of california, berkeley', 'occidental college',
#        'cal poly san luis obispo',
#        'university of california at los angeles (ucla)',
#        'university of california, san diego (ucsd)', 'pomona college',
#        'university of california, davis',
#        'university of california, irvine (uci)',
#        'san jose state university (sjsu)',
#        'california state university (csu), chico',
#        'california state university, fullerton (csuf)',
#        'san francisco state university (sfsu)',
#        'san diego state university (sdsu)',
#        'california state university, long beach (csulb)',
#        'california state university, east bay (csueb)',
#        'university of california, santa cruz (ucsc)',
#        'california state university, sacramento (csus)',
#        'thomas aquinas college', 'colorado school of mines',
# ...

# %%
salaries_by_region_Filtered.to_csv("salaries_by_region_Filtered.csv",index=False)

# %%
salaries_by_region_Filtered.head()
# Out:
#                           School Name      Region Starting Median Salary  \
# 1  california institute of technology  California             $75,500.00
# 2                 harvey mudd college  California             $71,800.00
# 3  university of california, berkeley  California             $59,900.00
# 4                  occidental college  California             $51,900.00
# 5            cal poly san luis obispo  California             $57,200.00
#
#   Mid-Career Median Salary Mid-Career 10th Percentile Salary  \
# 1              $123,000.00                               NaN
# 2              $122,000.00                               NaN
# 3              $112,000.00                        $59,500.00
# 4              $105,000.00                               NaN
# 5              $101,000.00                        $55,000.00
#
#   Mid-Career 25th Percentile Salary Mid-Career 75th Percentile Salary  \
# 1                       $104,000.00                       $161,000.00
# ...

# %%
most_recent_Cohorts_FD.head()
# Out:
#        UNITID  OPEID6             INSTNM CONTROL  MAIN  CIPCODE      CIPDESC  \
# 791  100858.0    1009  auburn university  Public     1      100  agriculture
# 814  100858.0    1009  auburn university  Public     1      305     forestry
# 815  100858.0    1009  auburn university  Public     1      305     forestry
# 816  100858.0    1009  auburn university  Public     1      305     forestry
# 817  100858.0    1009  auburn university  Public     1      305     forestry
#
#      CREDLEV                           CREDDESC  IPEDSCOUNT1  ...  \
# 791        3                  Bachelor's Degree         21.0  ...
# 814        3                  Bachelor's Degree         39.0  ...
# 815        5                    Master's Degree         10.0  ...
# 816        6                    Doctoral Degree          3.0  ...
# 817        8  Graduate/Professional Certificate          NaN  ...
#
#      EARN_COUNT_PELL_WNE_5YR EARN_PELL_WNE_MDN_5YR EARN_COUNT_NOPELL_WNE_5YR  \
# ...

# %%
most_recent_Cohorts_FD.columns
# Out:
# Index(['UNITID', 'OPEID6', 'INSTNM', 'CONTROL', 'MAIN', 'CIPCODE', 'CIPDESC',
#        'CREDLEV', 'CREDDESC', 'IPEDSCOUNT1',
#        ...
#        'EARN_COUNT_PELL_WNE_5YR', 'EARN_PELL_WNE_MDN_5YR',
#        'EARN_COUNT_NOPELL_WNE_5YR', 'EARN_NOPELL_WNE_MDN_5YR',
#        'EARN_COUNT_MALE_WNE_5YR', 'EARN_MALE_WNE_MDN_5YR',
#        'EARN_COUNT_NOMALE_WNE_5YR', 'EARN_NOMALE_WNE_MDN_5YR',
#        'EARN_COUNT_HIGH_CRED_5YR', 'EARN_IN_STATE_5YR'],
#       dtype='object', length=174)

# %%
(most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN'] == 'PS').sum()
# Out:
# 2539

# %%
 (most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MDN'] == 'PS').sum()
# Out:
# 2169

# %%
 (most_recent_Cohorts_FD['DEBT_ALL_STGP_EVAL_MEAN'] == 'PS').sum()
# Out:
# 2372

# %%
most_recent_Cohorts_FD = most_recent_Cohorts_FD.loc[:, ~most_recent_Cohorts_FD.columns.str.startswith('EARN_')]

# %%
most_recent_Cohorts_FD.columns
# Out:
# Index(['UNITID', 'OPEID6', 'INSTNM', 'CONTROL', 'MAIN', 'CIPCODE', 'CIPDESC',
#        'CREDLEV', 'CREDDESC', 'IPEDSCOUNT1',
#        ...
#        'BBRR4_FED_COMP_N', 'BBRR4_FED_COMP_DFLT', 'BBRR4_FED_COMP_DLNQ',
#        'BBRR4_FED_COMP_FBR', 'BBRR4_FED_COMP_DFR', 'BBRR4_FED_COMP_NOPROG',
#        'BBRR4_FED_COMP_MAKEPROG', 'BBRR4_FED_COMP_PAIDINFULL',
#        'BBRR4_FED_COMP_DISCHARGE', 'DISTANCE'],
#       dtype='object', length=112)

# %%
most_recent_Cohorts_FD = most_recent_Cohorts_FD.loc[:, ~most_recent_Cohorts_FD.columns.str.startswith('BBRR4_')]

# %%
most_recent_Cohorts_FD.columns
# Out:
# Index(['UNITID', 'OPEID6', 'INSTNM', 'CONTROL', 'MAIN', 'CIPCODE', 'CIPDESC',
#        'CREDLEV', 'CREDDESC', 'IPEDSCOUNT1',
#        ...
#        'BBRR1_FED_COMP_N', 'BBRR1_FED_COMP_DFLT', 'BBRR1_FED_COMP_DLNQ',
#        'BBRR1_FED_COMP_FBR', 'BBRR1_FED_COMP_DFR', 'BBRR1_FED_COMP_NOPROG',
#        'BBRR1_FED_COMP_MAKEPROG', 'BBRR1_FED_COMP_PAIDINFULL',
#        'BBRR1_FED_COMP_DISCHARGE', 'DISTANCE'],
#       dtype='object', length=103)

# %%
most_recent_Cohorts_FD = most_recent_Cohorts_FD.loc[:, ~most_recent_Cohorts_FD.columns.str.startswith('BBRR')]

# %%
most_recent_Cohorts_FD
# Out:
#           UNITID  OPEID6             INSTNM             CONTROL  MAIN  \
# 791     100858.0    1009  auburn university              Public     1
# 814     100858.0    1009  auburn university              Public     1
# 815     100858.0    1009  auburn university              Public     1
# 816     100858.0    1009  auburn university              Public     1
# 817     100858.0    1009  auburn university              Public     1
# ...          ...     ...                ...                 ...   ...
# 187793  237057.0    3803    whitman college  Private, nonprofit     1
# 187796  237057.0    3803    whitman college  Private, nonprofit     1
# 187798  237057.0    3803    whitman college  Private, nonprofit     1
# 187799  237057.0    3803    whitman college  Private, nonprofit     1
# 187801  237057.0    3803    whitman college  Private, nonprofit     1
#
#         CIPCODE      CIPDESC  CREDLEV                           CREDDESC  \
# ...

# %%
most_recent_Cohorts_FD.columns
# Out:
# Index(['UNITID', 'OPEID6', 'INSTNM', 'CONTROL', 'MAIN', 'CIPCODE', 'CIPDESC',
#        'CREDLEV', 'CREDDESC', 'IPEDSCOUNT1', 'IPEDSCOUNT2',
#        'DEBT_ALL_STGP_ANY_N', 'DEBT_ALL_STGP_ANY_MEAN',
#        'DEBT_ALL_STGP_ANY_MDN', 'DEBT_ALL_STGP_EVAL_N',
#        'DEBT_ALL_STGP_EVAL_MEAN', 'DEBT_ALL_STGP_EVAL_MDN',
#        'DEBT_ALL_PP_ANY_N', 'DEBT_ALL_PP_ANY_MEAN', 'DEBT_ALL_PP_ANY_MDN',
#        'DEBT_ALL_PP_EVAL_N', 'DEBT_ALL_PP_EVAL_MEAN', 'DEBT_ALL_PP_EVAL_MDN',
#        'DEBT_MALE_STGP_ANY_N', 'DEBT_MALE_STGP_ANY_MEAN',
#        'DEBT_MALE_STGP_ANY_MDN', 'DEBT_MALE_STGP_EVAL_N',
#        'DEBT_MALE_STGP_EVAL_MEAN', 'DEBT_MALE_STGP_EVAL_MDN',
#        'DEBT_MALE_PP_ANY_N', 'DEBT_MALE_PP_ANY_MEAN', 'DEBT_MALE_PP_ANY_MDN',
#        'DEBT_MALE_PP_EVAL_N', 'DEBT_MALE_PP_EVAL_MEAN',
#        'DEBT_MALE_PP_EVAL_MDN', 'DEBT_NOTMALE_STGP_ANY_N',
#        'DEBT_NOTMALE_STGP_ANY_MEAN', 'DEBT_NOTMALE_STGP_ANY_MDN',
#        'DEBT_NOTMALE_STGP_EVAL_N', 'DEBT_NOTMALE_STGP_EVAL_MEAN',
# ...

# %%
columns_to_keep=['INSTNM','CONTROL','CIPDESC','CREDDESC','DEBT_ALL_STGP_ANY_MEAN','DEBT_PELL_STGP_ANY_MEAN']

# %%
most_recent_Cohorts_FD=most_recent_Cohorts_FD[columns_to_keep]

# %%
most_recent_Cohorts_FD
# Out:
#                    INSTNM             CONTROL      CIPDESC  \
# 791     auburn university              Public  agriculture
# 814     auburn university              Public     forestry
# 815     auburn university              Public     forestry
# 816     auburn university              Public     forestry
# 817     auburn university              Public     forestry
# ...                   ...                 ...          ...
# 187793    whitman college  Private, nonprofit    sociology
# 187796    whitman college  Private, nonprofit        drama
# 187798    whitman college  Private, nonprofit  art history
# 187799    whitman college  Private, nonprofit        music
# 187801    whitman college  Private, nonprofit      history
#
#                                  CREDDESC DEBT_ALL_STGP_ANY_MEAN  \
# 791                     Bachelor's Degree                     PS
# 814                     Bachelor's Degree                     PS
# ...

# %%
most_recent_Cohorts_FD.to_csv("most_recent_Cohorts_FD.csv", index=False)

# %%
(most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN']=='PS').sum()
# Out:
# 2539

# %%
(most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN']!='PS').sum()
# Out:
# 399

# %%
most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN'].isna().sum()
# Out:
# 51

# %%
most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN'].unique()
# Out:
# array(['PS', nan, '19182', '27078', '22708', '21860', '22049', '19044',
#        '21291', '20207', '22047', '22785', '19698', '20329', '23562',
#        '21694', '23949', '23086', '19374', '22037', '21210', '19560',
#        '21285', '19152', '32343', '21117', '20093', '19783', '16827',
#        '20469', '23411', '21925', '19126', '20112', '19609', '23179',
#        '20920', '23277', '23709', '20717', '22101', '24997', '23355',
#        '22860', '22137', '22218', '24241', '24110', '20501', '21503',
#        '20163', '23210', '24564', '23497', '20064', '16680', '15948',
#        '17143', '22457', '20852', '20179', '20548', '22818', '22413',
#        '21890', '23134', '23624', '21028', '22224', '20988', '21713',
#        '21653', '21849', '19418', '24215', '27854', '22925', '25708',
#        '21040', '19632', '21474', '25588', '21053', '21832', '22117',
#        '24248', '18871', '20576', '18349', '23401', '27490', '22129',
# ...

# %%
df_no_ps = most_recent_Cohorts_FD[most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN'] != 'PS']

# %%
df_no_ps
# Out:
#                            INSTNM             CONTROL                 CIPDESC  \
# 817             auburn university              Public                forestry
# 829             auburn university              Public              journalism
# 832             auburn university              Public        computer science
# 874             auburn university              Public    chemical engineering
# 887             auburn university              Public  mechanical engineering
# ...                           ...                 ...                     ...
# 185845  university of puget sound  Private, nonprofit              psychology
# 185852  university of puget sound  Private, nonprofit             art history
# 185862  university of puget sound  Private, nonprofit                 history
# 187773            whitman college  Private, nonprofit                 biology
# 187791            whitman college  Private, nonprofit               economics
#
# ...

# %%
df_no_ps['DEBT_ALL_STGP_ANY_MEAN']=pd.to_numeric(df_no_ps['DEBT_ALL_STGP_ANY_MEAN'], errors='coerce')
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_32708\2342843369.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_ps['DEBT_ALL_STGP_ANY_MEAN']=pd.to_numeric(df_no_ps['DEBT_ALL_STGP_ANY_MEAN'], errors='coerce')

# %%
mean_values = df_no_ps['DEBT_ALL_STGP_ANY_MEAN'].mean()

# %%
mean_values
# Out:
# 21078.57183908046

# %%
most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN']=most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN'].fillna(mean_values)
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_32708\1584033185.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN']=most_recent_Cohorts_FD['DEBT_ALL_STGP_ANY_MEAN'].fillna(mean_values)

# %%
df_no_ps1 = most_recent_Cohorts_FD[most_recent_Cohorts_FD['DEBT_PELL_STGP_ANY_MEAN'] != 'PS']

# %%
df_no_ps1['DEBT_PELL_STGP_ANY_MEAN']=pd.to_numeric(df_no_ps1['DEBT_PELL_STGP_ANY_MEAN'], errors='coerce')
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_32708\2481278852.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_no_ps1['DEBT_PELL_STGP_ANY_MEAN']=pd.to_numeric(df_no_ps1['DEBT_PELL_STGP_ANY_MEAN'], errors='coerce')

# %%
mean_values1 = df_no_ps1['DEBT_PELL_STGP_ANY_MEAN'].mean()

# %%
mean_values1
# Out:
# 23018.248730964468

# %%
most_recent_Cohorts_FD['DEBT_PELL_STGP_ANY_MEAN']=most_recent_Cohorts_FD['DEBT_PELL_STGP_ANY_MEAN'].fillna(mean_values1)
# Out:
# C:\Users\athar\AppData\Local\Temp\ipykernel_32708\1024981964.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   most_recent_Cohorts_FD['DEBT_PELL_STGP_ANY_MEAN']=most_recent_Cohorts_FD['DEBT_PELL_STGP_ANY_MEAN'].fillna(mean_values1)

# %%
most_recent_Cohorts_FD
# Out:
#                    INSTNM             CONTROL      CIPDESC  \
# 791     auburn university              Public  agriculture
# 814     auburn university              Public     forestry
# 815     auburn university              Public     forestry
# 816     auburn university              Public     forestry
# 817     auburn university              Public     forestry
# ...                   ...                 ...          ...
# 187793    whitman college  Private, nonprofit    sociology
# 187796    whitman college  Private, nonprofit        drama
# 187798    whitman college  Private, nonprofit  art history
# 187799    whitman college  Private, nonprofit        music
# 187801    whitman college  Private, nonprofit      history
#
#                                  CREDDESC DEBT_ALL_STGP_ANY_MEAN  \
# 791                     Bachelor's Degree                     PS
# 814                     Bachelor's Degree                     PS
# ...

# %%
most_recent_Cohorts_FD.to_csv("most_recent_Cohorts_FD.csv",index=False)

# %%
Degree_pay.to_csv('degrees_that_pay_back_Filtered.csv',index=False)
